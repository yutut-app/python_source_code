# %% [markdown]
# # サポートベクターマシン

# %% [markdown]
# ## ライブラリーのインポート

# %%
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

# %% [markdown]
# ## データセットのインポート

# %%
# データセットをロード
dataset = datasets.load_breast_cancer()

# 一意なクラスラベルを出力
print('特徴量:', dataset.feature_names)
print('クラス:', np.unique(dataset.target))
# Out:
# 特徴量: ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness' 'mean compactness' 'mean concavity'
#  'mean concave points' 'mean symmetry' 'mean fractal dimension'
#  'radius error' 'texture error' 'perimeter error' 'area error'
#  'smoothness error' 'compactness error' 'concavity error'
#  'concave points error' 'symmetry error' 'fractal dimension error'
#  'worst radius' 'worst texture' 'worst perimeter' 'worst area'
#  'worst smoothness' 'worst compactness' 'worst concavity'
#  'worst concave points' 'worst symmetry' 'worst fractal dimension']
# クラス: [0 1]

# %% [markdown]
# ## データセットの確認

# %%
pd.set_option('display.max_columns', None)
# データセットの特徴量をDataFrameに変換
df = pd.DataFrame(dataset.data, columns=dataset.feature_names)

# 目標変数をDataFrameに追加
df['target'] = dataset.target
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  radius error  texture error  perimeter error  \
# 0                 0.07871        1.0950         0.9053            8.589
# 1                 0.05667        0.5435         0.7339            3.398
# 2                 0.05999        0.7456         0.7869            4.585
# 3                 0.09744        0.4956         1.1560            3.445
# 4                 0.05883        0.7572         0.7813            5.438
#
#    area error  smoothness error  compactness error  concavity error  \
# 0      153.40          0.006399            0.04904          0.05373
# 1       74.08          0.005225            0.01308          0.01860
# 2       94.03          0.006150            0.04006          0.03832
# 3       27.23          0.009110            0.07458          0.05661
# 4       94.44          0.011490            0.02461          0.05688
#
#    concave points error  symmetry error  fractal dimension error  \
# 0               0.01587         0.03003                 0.006193
# 1               0.01340         0.01389                 0.003532
# 2               0.02058         0.02250                 0.004571
# 3               0.01867         0.05963                 0.009208
# 4               0.01885         0.01756                 0.005115
#
#    worst radius  worst texture  worst perimeter  worst area  worst smoothness  \
# 0         25.38          17.33           184.60      2019.0            0.1622
# 1         24.99          23.41           158.80      1956.0            0.1238
# 2         23.57          25.53           152.50      1709.0            0.1444
# 3         14.91          26.50            98.87       567.7            0.2098
# 4         22.54          16.67           152.20      1575.0            0.1374
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    worst fractal dimension  target
# 0                  0.11890       0
# 1                  0.08902       0
# 2                  0.08758       0
# 3                  0.17300       0
# 4                  0.07678       0

# %%
print(f'データの形式：{df.shape}')
print(f'欠損値の数：{df.isnull().sum().sum()}')
# Out:
# データの形式：(569, 31)
# 欠損値の数：0

# %% [markdown]
# ## 相関関係の確認

# %%
corr_matrix = df.corr() # 相関行列を計算

# "target"との相関が高い順に列を並び替える
sorted_columns = corr_matrix.abs().sort_values('target', ascending=False).index

# 並び替えた列順でDataFrameの相関行列を表示
sorted_corr_matrix = corr_matrix[sorted_columns].loc[sorted_columns]
sorted_corr_matrix
# Out:
#                            target  worst concave points  worst perimeter  \
# target                   1.000000             -0.793566        -0.782914
# worst concave points    -0.793566              1.000000         0.816322
# worst perimeter         -0.782914              0.816322         1.000000
# mean concave points     -0.776614              0.910155         0.855923
# worst radius            -0.776454              0.787424         0.993708
# mean perimeter          -0.742636              0.771241         0.970387
# worst area              -0.733825              0.747419         0.977578
# mean radius             -0.730029              0.744214         0.965137
# mean area               -0.708984              0.722017         0.959120
# mean concavity          -0.696360              0.861323         0.729565
# worst concavity         -0.659610              0.855434         0.618344
# mean compactness        -0.596534              0.815573         0.590210
# worst compactness       -0.590998              0.801080         0.529408
# radius error            -0.567134              0.531062         0.719684
# perimeter error         -0.556141              0.554897         0.721031
# area error              -0.548236              0.538166         0.761213
# worst texture           -0.456903              0.359755         0.365098
# worst smoothness        -0.421465              0.547691         0.236775
# worst symmetry          -0.416294              0.502528         0.269493
# mean texture            -0.415185              0.295316         0.358040
# concave points error    -0.408042              0.602450         0.394999
# mean smoothness         -0.358560              0.503053         0.238853
# mean symmetry           -0.330499              0.430297         0.219169
# worst fractal dimension -0.323872              0.511114         0.138957
# compactness error       -0.292999              0.483208         0.260516
# concavity error         -0.253730              0.440472         0.226680
# fractal dimension error -0.077972              0.215204        -0.001000
# smoothness error         0.067016             -0.102007        -0.217304
# mean fractal dimension   0.012838              0.175325        -0.205151
# texture error            0.008303             -0.119638        -0.102242
# symmetry error           0.006522             -0.030413        -0.103753
#
#                          mean concave points  worst radius  mean perimeter  \
# target                             -0.776614     -0.776454       -0.742636
# worst concave points                0.910155      0.787424        0.771241
# worst perimeter                     0.855923      0.993708        0.970387
# mean concave points                 1.000000      0.830318        0.850977
# worst radius                        0.830318      1.000000        0.969476
# mean perimeter                      0.850977      0.969476        1.000000
# worst area                          0.809630      0.984015        0.941550
# mean radius                         0.822529      0.969539        0.997855
# mean area                           0.823269      0.962746        0.986507
# mean concavity                      0.921391      0.688236        0.716136
# worst concavity                     0.752399      0.573975        0.563879
# mean compactness                    0.831135      0.535315        0.556936
# worst compactness                   0.667454      0.475820        0.455774
# radius error                        0.698050      0.715065        0.691765
# perimeter error                     0.710650      0.697201        0.693135
# area error                          0.690299      0.757373        0.744983
# worst texture                       0.292752      0.359921        0.303038
# worst smoothness                    0.452753      0.216574        0.150549
# worst symmetry                      0.375744      0.243529        0.189115
# mean texture                        0.293464      0.352573        0.329533
# concave points error                0.615634      0.358127        0.407217
# mean smoothness                     0.553695      0.213120        0.207278
# mean symmetry                       0.462497      0.185728        0.183027
# worst fractal dimension             0.368661      0.093492        0.051019
# compactness error                   0.490424      0.204607        0.250744
# concavity error                     0.439167      0.186904        0.228082
# fractal dimension error             0.257584     -0.037488       -0.005523
# smoothness error                    0.027653     -0.230691       -0.202694
# mean fractal dimension              0.166917     -0.253691       -0.261477
# texture error                       0.021480     -0.111690       -0.086761
# symmetry error                      0.095351     -0.128121       -0.081629
#
#                          worst area  mean radius  mean area  mean concavity  \
# target                    -0.733825    -0.730029  -0.708984       -0.696360
# worst concave points       0.747419     0.744214   0.722017        0.861323
# worst perimeter            0.977578     0.965137   0.959120        0.729565
# mean concave points        0.809630     0.822529   0.823269        0.921391
# worst radius               0.984015     0.969539   0.962746        0.688236
# mean perimeter             0.941550     0.997855   0.986507        0.716136
# worst area                 1.000000     0.941082   0.959213        0.675987
# mean radius                0.941082     1.000000   0.987357        0.676764
# mean area                  0.959213     0.987357   1.000000        0.685983
# mean concavity             0.675987     0.676764   0.685983        1.000000
# worst concavity            0.543331     0.526911   0.512606        0.884103
# mean compactness           0.509604     0.506124   0.498502        0.883121
# worst compactness          0.438296     0.413463   0.390410        0.754968
# radius error               0.751548     0.679090   0.732562        0.631925
# perimeter error            0.730713     0.674172   0.726628        0.660391
# area error                 0.811408     0.735864   0.800086        0.617427
# worst texture              0.345842     0.297008   0.287489        0.299879
# worst smoothness           0.209145     0.119616   0.123523        0.448822
# worst symmetry             0.209146     0.163953   0.143570        0.409464
# mean texture               0.343546     0.323782   0.321086        0.302418
# concave points error       0.342271     0.376169   0.372320        0.683260
# mean smoothness            0.206718     0.170581   0.177028        0.521984
# mean symmetry              0.177193     0.147741   0.151293        0.500667
# worst fractal dimension    0.079647     0.007066   0.003738        0.514930
# compactness error          0.199371     0.206000   0.212583        0.670279
# concavity error            0.188353     0.194204   0.207660        0.691270
# fractal dimension error   -0.022736    -0.042641  -0.019887        0.449301
# smoothness error          -0.182195    -0.222600  -0.166777        0.098564
# mean fractal dimension    -0.231854    -0.311631  -0.283110        0.336783
# texture error             -0.083195    -0.097317  -0.066280        0.076218
# symmetry error            -0.110343    -0.104321  -0.072497        0.178009
#
#                          worst concavity  mean compactness  worst compactness  \
# target                         -0.659610         -0.596534          -0.590998
# worst concave points            0.855434          0.815573           0.801080
# worst perimeter                 0.618344          0.590210           0.529408
# mean concave points             0.752399          0.831135           0.667454
# worst radius                    0.573975          0.535315           0.475820
# mean perimeter                  0.563879          0.556936           0.455774
# worst area                      0.543331          0.509604           0.438296
# mean radius                     0.526911          0.506124           0.413463
# mean area                       0.512606          0.498502           0.390410
# mean concavity                  0.884103          0.883121           0.754968
# worst concavity                 1.000000          0.816275           0.892261
# mean compactness                0.816275          1.000000           0.865809
# worst compactness               0.892261          0.865809           1.000000
# radius error                    0.380585          0.497473           0.287103
# perimeter error                 0.418899          0.548905           0.341919
# area error                      0.385100          0.455653           0.283257
# worst texture                   0.368366          0.248133           0.360832
# worst smoothness                0.518523          0.565541           0.568187
# worst symmetry                  0.532520          0.510223           0.614441
# mean texture                    0.301025          0.236702           0.277830
# concave points error            0.549592          0.642262           0.452888
# mean smoothness                 0.434926          0.659123           0.472468
# mean symmetry                   0.433721          0.602641           0.473200
# worst fractal dimension         0.686511          0.687382           0.810455
# compactness error               0.639147          0.738722           0.678780
# concavity error                 0.662564          0.570517           0.484858
# fractal dimension error         0.379975          0.507318           0.390159
# smoothness error               -0.058298          0.135299          -0.055558
# mean fractal dimension          0.346234          0.565369           0.458798
# texture error                  -0.068956          0.046205          -0.092439
# symmetry error                  0.037119          0.229977           0.060255
#
#                          radius error  perimeter error  area error  \
# target                      -0.567134        -0.556141   -0.548236
# worst concave points         0.531062         0.554897    0.538166
# worst perimeter              0.719684         0.721031    0.761213
# mean concave points          0.698050         0.710650    0.690299
# worst radius                 0.715065         0.697201    0.757373
# mean perimeter               0.691765         0.693135    0.744983
# worst area                   0.751548         0.730713    0.811408
# mean radius                  0.679090         0.674172    0.735864
# mean area                    0.732562         0.726628    0.800086
# mean concavity               0.631925         0.660391    0.617427
# worst concavity              0.380585         0.418899    0.385100
# mean compactness             0.497473         0.548905    0.455653
# worst compactness            0.287103         0.341919    0.283257
# radius error                 1.000000         0.972794    0.951830
# perimeter error              0.972794         1.000000    0.937655
# area error                   0.951830         0.937655    1.000000
# worst texture                0.194799         0.200371    0.196497
# worst smoothness             0.141919         0.130054    0.125389
# worst symmetry               0.094543         0.109930    0.074126
# mean texture                 0.275869         0.281673    0.259845
# concave points error         0.513346         0.556264    0.415730
# mean smoothness              0.301467         0.296092    0.246552
# mean symmetry                0.303379         0.313893    0.223970
# worst fractal dimension      0.049559         0.085433    0.017539
# compactness error            0.356065         0.416322    0.284840
# concavity error              0.332358         0.362482    0.270895
# fractal dimension error      0.227754         0.244143    0.127071
# smoothness error             0.164514         0.151075    0.075150
# mean fractal dimension       0.000111         0.039830   -0.090170
# texture error                0.213247         0.223171    0.111567
# symmetry error               0.240567         0.266487    0.134109
#
#                          worst texture  worst smoothness  worst symmetry  \
# target                       -0.456903         -0.421465       -0.416294
# worst concave points          0.359755          0.547691        0.502528
# worst perimeter               0.365098          0.236775        0.269493
# mean concave points           0.292752          0.452753        0.375744
# worst radius                  0.359921          0.216574        0.243529
# mean perimeter                0.303038          0.150549        0.189115
# worst area                    0.345842          0.209145        0.209146
# mean radius                   0.297008          0.119616        0.163953
# mean area                     0.287489          0.123523        0.143570
# mean concavity                0.299879          0.448822        0.409464
# worst concavity               0.368366          0.518523        0.532520
# mean compactness              0.248133          0.565541        0.510223
# worst compactness             0.360832          0.568187        0.614441
# radius error                  0.194799          0.141919        0.094543
# perimeter error               0.200371          0.130054        0.109930
# area error                    0.196497          0.125389        0.074126
# worst texture                 1.000000          0.225429        0.233027
# worst smoothness              0.225429          1.000000        0.493838
# worst symmetry                0.233027          0.493838        1.000000
# mean texture                  0.912045          0.077503        0.105008
# concave points error          0.086741          0.215351        0.143116
# mean smoothness               0.036072          0.805324        0.394309
# mean symmetry                 0.090651          0.426675        0.699826
# worst fractal dimension       0.219122          0.617624        0.537848
# compactness error             0.143003          0.227394        0.277878
# concavity error               0.100241          0.168481        0.197788
# fractal dimension error      -0.003195          0.170568        0.111094
# smoothness error             -0.074743          0.314457       -0.107342
# mean fractal dimension       -0.051269          0.504942        0.334019
# texture error                 0.409003         -0.073658       -0.128215
# symmetry error               -0.077473         -0.012662        0.389402
#
#                          mean texture  concave points error  mean smoothness  \
# target                      -0.415185             -0.408042        -0.358560
# worst concave points         0.295316              0.602450         0.503053
# worst perimeter              0.358040              0.394999         0.238853
# mean concave points          0.293464              0.615634         0.553695
# worst radius                 0.352573              0.358127         0.213120
# mean perimeter               0.329533              0.407217         0.207278
# worst area                   0.343546              0.342271         0.206718
# mean radius                  0.323782              0.376169         0.170581
# mean area                    0.321086              0.372320         0.177028
# mean concavity               0.302418              0.683260         0.521984
# worst concavity              0.301025              0.549592         0.434926
# mean compactness             0.236702              0.642262         0.659123
# worst compactness            0.277830              0.452888         0.472468
# radius error                 0.275869              0.513346         0.301467
# perimeter error              0.281673              0.556264         0.296092
# area error                   0.259845              0.415730         0.246552
# worst texture                0.912045              0.086741         0.036072
# worst smoothness             0.077503              0.215351         0.805324
# worst symmetry               0.105008              0.143116         0.394309
# mean texture                 1.000000              0.163851        -0.023389
# concave points error         0.163851              1.000000         0.380676
# mean smoothness             -0.023389              0.380676         1.000000
# mean symmetry                0.071401              0.393298         0.557775
# worst fractal dimension      0.119205              0.310655         0.499316
# compactness error            0.191975              0.744083         0.318943
# concavity error              0.143293              0.771804         0.248396
# fractal dimension error      0.054458              0.611044         0.283607
# smoothness error             0.006614              0.328429         0.332375
# mean fractal dimension      -0.076437              0.341198         0.584792
# texture error                0.386358              0.230283         0.068406
# symmetry error               0.009127              0.312780         0.200774
#
#                          mean symmetry  worst fractal dimension  \
# target                       -0.330499                -0.323872
# worst concave points          0.430297                 0.511114
# worst perimeter               0.219169                 0.138957
# mean concave points           0.462497                 0.368661
# worst radius                  0.185728                 0.093492
# mean perimeter                0.183027                 0.051019
# worst area                    0.177193                 0.079647
# mean radius                   0.147741                 0.007066
# mean area                     0.151293                 0.003738
# mean concavity                0.500667                 0.514930
# worst concavity               0.433721                 0.686511
# mean compactness              0.602641                 0.687382
# worst compactness             0.473200                 0.810455
# radius error                  0.303379                 0.049559
# perimeter error               0.313893                 0.085433
# area error                    0.223970                 0.017539
# worst texture                 0.090651                 0.219122
# worst smoothness              0.426675                 0.617624
# worst symmetry                0.699826                 0.537848
# mean texture                  0.071401                 0.119205
# concave points error          0.393298                 0.310655
# mean smoothness               0.557775                 0.499316
# mean symmetry                 1.000000                 0.438413
# worst fractal dimension       0.438413                 1.000000
# compactness error             0.421659                 0.590973
# concavity error               0.342627                 0.439329
# fractal dimension error       0.331786                 0.591328
# smoothness error              0.187321                 0.101480
# mean fractal dimension        0.479921                 0.767297
# texture error                 0.128053                -0.045655
# symmetry error                0.449137                 0.078079
#
#                          compactness error  concavity error  \
# target                           -0.292999        -0.253730
# worst concave points              0.483208         0.440472
# worst perimeter                   0.260516         0.226680
# mean concave points               0.490424         0.439167
# worst radius                      0.204607         0.186904
# mean perimeter                    0.250744         0.228082
# worst area                        0.199371         0.188353
# mean radius                       0.206000         0.194204
# mean area                         0.212583         0.207660
# mean concavity                    0.670279         0.691270
# worst concavity                   0.639147         0.662564
# mean compactness                  0.738722         0.570517
# worst compactness                 0.678780         0.484858
# radius error                      0.356065         0.332358
# perimeter error                   0.416322         0.362482
# area error                        0.284840         0.270895
# worst texture                     0.143003         0.100241
# worst smoothness                  0.227394         0.168481
# worst symmetry                    0.277878         0.197788
# mean texture                      0.191975         0.143293
# concave points error              0.744083         0.771804
# mean smoothness                   0.318943         0.248396
# mean symmetry                     0.421659         0.342627
# worst fractal dimension           0.590973         0.439329
# compactness error                 1.000000         0.801268
# concavity error                   0.801268         1.000000
# fractal dimension error           0.803269         0.727372
# smoothness error                  0.336696         0.268685
# mean fractal dimension            0.559837         0.446630
# texture error                     0.231700         0.194998
# symmetry error                    0.394713         0.309429
#
#                          fractal dimension error  smoothness error  \
# target                                 -0.077972          0.067016
# worst concave points                    0.215204         -0.102007
# worst perimeter                        -0.001000         -0.217304
# mean concave points                     0.257584          0.027653
# worst radius                           -0.037488         -0.230691
# mean perimeter                         -0.005523         -0.202694
# worst area                             -0.022736         -0.182195
# mean radius                            -0.042641         -0.222600
# mean area                              -0.019887         -0.166777
# mean concavity                          0.449301          0.098564
# worst concavity                         0.379975         -0.058298
# mean compactness                        0.507318          0.135299
# worst compactness                       0.390159         -0.055558
# radius error                            0.227754          0.164514
# perimeter error                         0.244143          0.151075
# area error                              0.127071          0.075150
# worst texture                          -0.003195         -0.074743
# worst smoothness                        0.170568          0.314457
# worst symmetry                          0.111094         -0.107342
# mean texture                            0.054458          0.006614
# concave points error                    0.611044          0.328429
# mean smoothness                         0.283607          0.332375
# mean symmetry                           0.331786          0.187321
# worst fractal dimension                 0.591328          0.101480
# compactness error                       0.803269          0.336696
# concavity error                         0.727372          0.268685
# fractal dimension error                 1.000000          0.427374
# smoothness error                        0.427374          1.000000
# mean fractal dimension                  0.688132          0.401964
# texture error                           0.279723          0.397243
# symmetry error                          0.369078          0.413506
#
#                          mean fractal dimension  texture error  symmetry error
# target                                 0.012838       0.008303        0.006522
# worst concave points                   0.175325      -0.119638       -0.030413
# worst perimeter                       -0.205151      -0.102242       -0.103753
# mean concave points                    0.166917       0.021480        0.095351
# worst radius                          -0.253691      -0.111690       -0.128121
# mean perimeter                        -0.261477      -0.086761       -0.081629
# worst area                            -0.231854      -0.083195       -0.110343
# mean radius                           -0.311631      -0.097317       -0.104321
# mean area                             -0.283110      -0.066280       -0.072497
# mean concavity                         0.336783       0.076218        0.178009
# worst concavity                        0.346234      -0.068956        0.037119
# mean compactness                       0.565369       0.046205        0.229977
# worst compactness                      0.458798      -0.092439        0.060255
# radius error                           0.000111       0.213247        0.240567
# perimeter error                        0.039830       0.223171        0.266487
# area error                            -0.090170       0.111567        0.134109
# worst texture                         -0.051269       0.409003       -0.077473
# worst smoothness                       0.504942      -0.073658       -0.012662
# worst symmetry                         0.334019      -0.128215        0.389402
# mean texture                          -0.076437       0.386358        0.009127
# concave points error                   0.341198       0.230283        0.312780
# mean smoothness                        0.584792       0.068406        0.200774
# mean symmetry                          0.479921       0.128053        0.449137
# worst fractal dimension                0.767297      -0.045655        0.078079
# compactness error                      0.559837       0.231700        0.394713
# concavity error                        0.446630       0.194998        0.309429
# fractal dimension error                0.688132       0.279723        0.369078
# smoothness error                       0.401964       0.397243        0.413506
# mean fractal dimension                 1.000000       0.164174        0.345007
# texture error                          0.164174       1.000000        0.411621
# symmetry error                         0.345007       0.411621        1.000000

# %% [markdown]
# ## 説明変数と目的変数に分割

# %%
# 相関関係の高い2つの特徴量を抽出
select_features = ['worst perimeter', 'worst concave points']
X = df.loc[:, select_features].values
y = df.loc[:, 'target'].values

# %% [markdown]
# ## 訓練データとテストデータに分割

# %%
# 全体の30%をテストデータととする
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=0, stratify=y)

# %%
# 各データセットのラベルの比率
print('入力データセットのyラベルの比率:', np.bincount(y))
print('訓練サブセットのyラベルの比率:', np.bincount(y_train))
print('テストサブセットのyラベルの比率:', np.bincount(y_test))
# Out:
# 入力データセットのyラベルの比率: [212 357]
# 訓練サブセットのyラベルの比率: [148 250]
# テストサブセットのyラベルの比率: [ 64 107]

# %% [markdown]
# ## 特徴量のスケーリング

# %%
sc = StandardScaler()
# 訓練データの平均と標準偏差を計算
sc.fit(X_train)
# 平均と標準偏差を用いて標準化
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# %% [markdown]
# ## 訓練データによるモデルの学習

# %%
# 線形SVMのインスタンスを生成
classifier = SVC(kernel='linear', C=1.0, random_state=0)
# 訓練データをモデルに適合させる
classifier.fit(X_train_std, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %% [markdown]
# ## 新しいデータポイントでの予測

# %%
# 新しいデータポイントで予測
new_data = [[-1,1]]
pred_label = classifier.predict(sc.transform(new_data))[0]
print(f'予測したクラス:{pred_label}({dataset.target_names[pred_label]})')
# Out:
# 予測したクラス:0(malignant)

# %% [markdown]
# ## テストデータで予測

# %%
# テストデータで予測を実施
y_pred = classifier.predict(X_test_std)

# %% [markdown]
# ## モデルの性能評価

# %%
# 正分類のデータ点の個数を表示
print(f'正分類のデータ点: {(y_test == y_pred).sum()}個/{len(y_test)}個' )

# 分類の正解率を表示
print(f'Accuracy(Test): {accuracy_score(y_test, y_pred):.3f}')
# Out:
# 正分類のデータ点: 155個/171個
# Accuracy(Test): 0.906

# %% [markdown]
# ## 性能評価の可視化

# %%
# 訓練データとテストデータの最小値と最大値を計算
def calculate_bounds(X1, X2):
    X1_min, X1_max = X1.min() - (X1.max()-X1.min())/20, X1.max() + (X1.max()-X1.min())/20
    X2_min, X2_max = X2.min() - (X2.max()-X2.min())/20, X2.max() + (X2.max()-X2.min())/20
    return X1_min, X1_max, X2_min, X2_max

# %%
def plot_data(ax, X_set, y_set, X1, X2, Z, colors, kind, classifier):
    cmap = ListedColormap(colors[:len(np.unique(y_set))])
    ax.contourf(X1, X2, Z, alpha=0.3, cmap=cmap)
    for idx, feature in enumerate(np.unique(y_set)):
        ax.scatter(x=X_set[y_set == feature, 0], 
                   y=X_set[y_set == feature, 1],
                   alpha=0.5, 
                   color=colors[idx],
                   marker='o', 
                   label=dataset.target_names[feature], 
                   edgecolor='black')
    ax.set_xlabel(select_features[0])
    ax.set_ylabel(select_features[1])
    ax.set_title(f'{type(classifier).__name__} ({kind})')
    ax.legend(loc='best')

# %%
def plot_decision_regions(X_train_std, X_test_std, y_train, y_test, classifier):
    # マーカーとカラーマップの準備
    colors = ('red', 'blue', "green")
    
    # スケーリング前の元のデータに変換
    X_train_set, y_train_set = sc.inverse_transform(X_train_std), y_train
    X_test_set, y_test_set = sc.inverse_transform(X_test_std), y_test
    
    # 訓練データとテストデータの範囲を統一
    X_combined = np.vstack((X_train_set, X_test_set))
    X1_min, X1_max, X2_min, X2_max = calculate_bounds(X_combined[:, 0], X_combined[:, 1])
    
    # グリッドポイントの生成
    X1, X2 = np.meshgrid(np.arange(X1_min, X1_max, step=(X1_max - X1_min) / 1000),
                         np.arange(X2_min, X2_max, step=(X2_max - X2_min) / 1000))
    # 各特徴を1次元配列に変換して予測を実行
    Z = classifier.predict(sc.transform(np.array([X1.ravel(), X2.ravel()]).T))
    # 予測結果を元のグリッドポイントのデータサイズに変換
    Z = Z.reshape(X1.shape)
    
    fig, ax = plt.subplots(1, 2, figsize=(8, 4))
    
    # 訓練データとテストデータのプロット
    plot_data(ax[0], X_train_set, y_train_set, X1, X2, Z, colors, "Training set", classifier)
    plot_data(ax[1], X_test_set, y_test_set, X1, X2, Z, colors, "Test set", classifier)
    
    plt.tight_layout()
    plt.show()

# %%
# 決定境界のプロット
if len(select_features) == 2:
    plot_decision_regions(X_train_std, X_test_std, y_train, y_test, classifier)
else:
    print("特徴量が2個の場合のみプロットが可能です。選択された特徴量の数:", len(select_features))
